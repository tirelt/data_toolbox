# %%
# If you would like to install packages that are not installed by default, you may do so here.
# For example:

# import sys
# !{sys.executable} -m pip install package1 package2

# %%
# Import libraries
import numpy as np
import pandas as pd
import sys
sys.path.append("../") 
from src.data_analysis import *
from tqdm.auto import tqdm
tqdm.pandas()

# %%
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
# Read dataset
df = pd.read_csv("../data/titanic/train.csv") # changed index_col
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape[0]
# Out:
# 646

# %%
df_analysis = check_data(df)
df_analysis
# Out:
#         Feature  NaN Unique                                            Type
# 0   PassengerId    0    891                          [(<class 'int'>, 891)]
# 1      Survived    0      2                          [(<class 'int'>, 891)]
# 2        Pclass    0      3                          [(<class 'int'>, 891)]
# 3          Name    0    891                          [(<class 'str'>, 891)]
# 4           Sex    0      2                          [(<class 'str'>, 891)]
# 5           Age  177    265                        [(<class 'float'>, 891)]
# 6         SibSp    0      7                          [(<class 'int'>, 891)]
# 7         Parch    0      7                          [(<class 'int'>, 891)]
# 8        Ticket    0    681                          [(<class 'str'>, 891)]
# 9          Fare    0    248                        [(<class 'float'>, 891)]
# 10        Cabin  687    148  [(<class 'float'>, 687), (<class 'str'>, 204)]
# ...

# %%
df = df.drop_duplicates(keep='first') #drop duplicate

# %%
df["Sex_nbr"]=df["Sex"].apply(lambda x: 1 if x== 'male' else 0) #create column

# %%
df = df[(df["Age"] >= 12 ) & ~(pd.isnull(df["Age"]))] #remove babies an missing age

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=df["Fare"],histnorm="percent"))#,nbinsx=10
fig.update_layout(title='Histogram title')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_43.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df[df['Fare'] >= 200].sort_values(by="Fare",ascending=False).dropna() #check outlier
# Out:
#      PassengerId  Survived  Pclass  \
# 737          738         1       1
# 679          680         1       1
# 27            28         0       1
# 341          342         1       1
# 88            89         1       1
# 438          439         0       1
# 311          312         1       1
# 742          743         1       1
# 299          300         1       1
# 118          119         0       1
# 700          701         1       1
# 716          717         1       1
# 377          378         0       1
# 689          690         1       1
# 730          731         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 737                             Lesurer, Mr. Gustave J    male  35.0      0
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...
